# %%
import networkx as nx

# %%
G = nx.DiGraph()

# %%
nodes = ['extraction', 'post_processing', 'cross_sell_flags', 'etl_rollup', 'submission', 'submission_rollup',\
         'model']
# G.add_nodes_from(nodes, exec_time = [35, 4, 7, 5, 15, 1, 340])

# %%
G.add_edges_from([('extraction', 'post_processing'), ('post_processing', 'cross_sell_flags'),
                  ('cross_sell_flags', 'etl_rollup'), ('submission', 'submission_rollup'),
                  ('submission_rollup', 'model'), ('etl_rollup', 'model')
                 ])

# %%
space = [(0,0), (0,-1), (0,-2), (0,-3), (3,0), (3,-1), (2,-4)]

# %%
nx.draw_networkx(G, edge_color='r', **{'pos':pos, 'with_labels':True, 'arrows':True})

# %%
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos)
nx.draw_networkx_edges(G,pos)

# %%
pos = dict(zip(nodes, space))
nx.draw_networkx(G, **{'pos':pos, 'with_labels':True, 'arrows':True})

# %%
# add 5 nodes, labeled 0-4:

# 1,2 depend on 0:
G.add_edge(0,1)
G.add_edge(0,2)
# 3 depends on 1,2
G.add_edge(1,3)
G.add_edge(2,3)
# 4 depends on 1
G.add_edge(1,4)

# now draw the graph:
pos = { 0 : (0,0), 1 : (1,1), 2 : (-1,1),
        3 : (0,2), 4 : (2,2)}
nx.draw(G, pos, edge_color='r')
